# %%
import ipywidgets as widgets
import pandas as pd


candidatosDepEstadual = pd.read_csv("candidatosDepEstadual.csv")
# candidatosDepEstadual['DS_GENERO'].value_counts()
# candidatosDepEstadual['DS_COR_RACA'].unique()
candidatosDepEstadual['IDEOLOGIA_PARTIDO'].unique()
# candidatosDepEstadual.columns

# candidatosDepEstadual = candidatosDepEstadual.query("(DS_GENERO == 'FEMININO') & (DS_COR_RACA == 'PARDA' | DS_COR_RACA == 'PRETA' | DS_COR_RACA == 'AMARELA' | DS_COR_RACA == 'INDÍGENA')")

# candidatosDepEstadual.shape[0]


candidatosDepEstadual['selecao'] = candidatosDepEstadual['NM_URNA_CANDIDATO'] + " - " + candidatosDepEstadual['NR_CANDIDATO'].astype(str)

candidatosDepEstadual['selecao']

global voto 
voto = candidatosDepEstadual['selecao'].tolist()
voto

# %%
import ipywidgets as widgets
import pandas as pd




# data = {"label_1":"data_1", "label_2":"data_2", "label_3":"data_3"}
filtroGenero = ["DS_GENERO == 'MASCULINO'","DS_GENERO == 'FEMININO'","DS_COR_RACA == 'BRANCA'","DS_COR_RACA == 'PARDA'","DS_COR_RACA == 'PRETA'","DS_COR_RACA == 'AMARELA'","DS_COR_RACA == 'INDÍGENA'","IDEOLOGIA_PARTIDO == 'Esquerda'", "IDEOLOGIA_PARTIDO == 'Direita'", "IDEOLOGIA_PARTIDO == 'Centro'"]
filtroGeneroTitulos = ["Homem","Mulher",'Branca','Parda','Preta','Amarela','Indígena','Esquerda','Direita','Centro']


names = []
checkbox_objects = []
for idx,key in enumerate(filtroGenero):
    checkbox_objects.append(widgets.Checkbox(value=False, description=filtroGeneroTitulos[idx]))
    names.append(key)

arg_dict = {names[i]: checkbox for i, checkbox in enumerate(checkbox_objects)}

ui = widgets.HBox(children=checkbox_objects)

selected_data = []
def select_data(**kwargs):
    selected_data.clear()

    for key in kwargs:
        if kwargs[key] is True:
            selected_data.append(key)
    # print(selected_data)


    if len(selected_data) > 0: 
        
        
        listaGenero = [if x for selected_data if x == "DS_GENERO"]
        print(listaGenero)
        
        selection = " | ".join(selected_data)
        candidatosDepEstadual = pd.read_csv("candidatosDepEstadual.csv")
        
        candidatosDepEstadual = candidatosDepEstadual.query(selection)
        display(candidatosDepEstadual)
#     if len(selected_data) > 0:    
#         df = df[df.Fruit==selected_data[0]]
#         display(df)
    
    
out = widgets.interactive_output(select_data, arg_dict)
display(ui, out)
# Out:
#   Cell In [23], line 35
#     listaGenero = [if x for selected_data if x == "DS_GENERO"]
#                    ^
# SyntaxError: invalid syntax

# %%
import ipywidgets as widgets
import pandas as pd

filtro = ["DS_GENERO == 'MASCULINO'","DS_GENERO == 'FEMININO'","DS_COR_RACA == 'BRANCA'","DS_COR_RACA == 'PARDA'","DS_COR_RACA == 'PRETA'","DS_COR_RACA == 'AMARELA'","DS_COR_RACA == 'INDÍGENA'","IDEOLOGIA_PARTIDO == 'Esquerda'", "IDEOLOGIA_PARTIDO == 'Direita'", "IDEOLOGIA_PARTIDO == 'Centro'"]
filtroTitulos = ["Homem","Mulher",'Branca','Parda','Preta','Amarela','Indígena','Esquerda','Direita','Centro']


names = []
checkbox_objects = []
for idx,key in enumerate(filtro):
    checkbox_objects.append(widgets.Checkbox(value=False, description=filtroTitulos[idx]))
    names.append(key)

arg_dict = {names[i]: checkbox for i, checkbox in enumerate(checkbox_objects)}

ui = widgets.GridBox(children=checkbox_objects,layout=widgets.Layout(grid_template_columns="repeat(4, 100px)"))

selected_data = []
def select_data(**kwargs):
    selected_data.clear()

    for key in kwargs:
        if kwargs[key] is True:
            selected_data.append(key)


    if len(selected_data) > 0: 
        
        listaGenero = [x for x in selected_data if "DS_GENERO" in x]
        listaEtnia = [x for x in selected_data if "DS_COR_RACA" in x]
        listaIdeologia = [x for x in selected_data if "IDEOLOGIA_PARTIDO" in x]

        stringGenero = "("+" | ".join(listaGenero)+")"        
        stringEtnia = "("+" | ".join(listaEtnia)+")"
        stringIdeologia = "("+" | ".join(listaIdeologia)+")"
        
        selection = f"{stringGenero}{' & '+stringEtnia if len(listaEtnia) > 0 else ''}{' & '+stringIdeologia if len(listaIdeologia) > 0 else ''}"
        
        candidatosDepEstadual = pd.read_csv("candidatosDepEstadual.csv")
        
        candidatosDepEstadual = candidatosDepEstadual.query(selection)
        display(candidatosDepEstadual)
        

        coluna = candidatosDepEstadual['NM_URNA_CANDIDATO'] + " - " + candidatosDepEstadual['NR_CANDIDATO'].astype(str)

        
        global voto 
        voto = coluna.tolist()
        
        # candidatosDepEstadual['selecao']

        # return candidatosDepEstadual
    
out = widgets.interactive_output(select_data, arg_dict)
display(ui, out)
# Out:
# GridBox(children=(Checkbox(value=False, description='Homem'), Checkbox(value=False, description='Mulher'), Che…
# Output()

# %%
voto
# Out:
# ['LUIZA DULCI - 13113',
#  'ROSELI BRITO - 18456',
#  'GRACIELE LIMA - 65321',
#  'EDNA RIBEIRO - 13666',
#  'DANIELLE LIO - 18244',
#  'DANIELE BIONDO CROCETTI - 18294',
#  'NICINHA - 33800',
#  'ADVOGADA ROSANE - 50500',
#  'DRA FABIOLA MANSUR - 40040',
#  'PROFESSORA JOSETE - 13613',
#  'ANDREA NERI SANTANA - 40600',
#  'PATRICIA SALES - 23012',
#  'JANAÍNA GOMES - 12555',
#  'CECÍLIA - 18194',
#  'JANETE CARVALHO - 18881',
#  'JOYCE CABELEIREIRA - 40140',
#  'ELEUZA DIAS - 13131',
#  'DANNI DIAS - 23456',
#  'PROF ENFERMEIRA SANDRA ASSANTE - 18888',
#  'ROSELI MATOS - 65456',
#  'ISAURA LEMOS - 65123',
#  'ANA JÚLIA - 13213',
#  'RAFAELLA RODRIGUES - 18789',
#  'RITA UIARA - 18110',
#  'ZEIDAN - 13103',
#  'TIA LU DA RECICLAGEM - 40132',
#  'MEIRY OLIVEIRA - 12287',
#  'SUELY BARRETO - 23023',
#  'MARIANA SOARES - 40234',
#  'LEIA WAGNER - 18144',
#  'GLEYCE KELLY DOS RITMOS - 40321',
#  'VALERIA-COLETIVO DE MULHERES  - 50367',
#  'MICHELLE DA BANCADA DO BATOM - 13111',
#  'VERA DA SÃO RAFAEL - 50110',
#  'PROFESSORA VILANI - 50180',
#  'LEIDE MENGATTI - 40112',
#  'JANNE RUTH - 12344',
#  'LORELENE L. DA SILVA - 40730',
#  'MIRIS SALMITO - 33300',
#  'DRA RAFAELA VIEIRA - 12345',
#  'LAUANA JUHLIA TAINA - 50111',
#  'BEATRIZ CERQUEIRA - 13123',
#  'KATIANY  - 16160',
#  'ISNAR ROCHA - 43222',
#  'PROF. JOYCIMARA - 12455',
#  'PAULINHA DO POVO - 40489',
#  'TATIANNY DA COLETIVA FEMINISTA - 50111',
#  'ANDREIA SOUZA - 12369',
#  'NEUSA BENEDITO - 23023',
#  'INÊS PAZ - 50050',
#  'ARLANE FREITAS - 33099',
#  'NINA GOMES - 40222',
#  'NATÁLIA PIMENTA - 29029',
#  'LUANA RIBEIRO - 65123',
#  'LUCIANA RAFAGNIN - 13233',
#  'DENISE LIMA - 65555',
#  'SUELLEN ALMEIDA - 23500',
#  'DARLEM LEMOS - 33169',
#  'MACAÉ EVARISTO - 13130',
#  'MIRAM MACHADO - 18183',
#  'LUANA DE SOUZA - 13313',
#  'PROFESSORA INÊS - 18123',
#  'LEDA LIMA - 12777',
#  'ERACY PIMENTEL - 40136',
#  'DEBORA CAROLINE - 33200',
#  'CLEIDE CABELEREIRA - 33025',
#  'PATRÍCIA LOPES - 23233',
#  'ALESSANDRA SILVA - 40567',
#  'MARILEIDE PEREIRA - 43633',
#  'PROFESSORA ANTÔNIA DE MARIA - 50456',
#  'REGIANE JUNTOS SOMOS + FORTES - 13033',
#  'ANTÔNIA CUTRIM - 43333',
#  'DRA VIVIANNE - 12456',
#  'LÍVIA NORONHA - 50180',
#  'MARCIA CRISTINA - 43180',
#  'MISSIONARIA VERA - 33431',
#  'RAFA GALOSSI - 50180',
#  'SOL PROTETORA - 43197',
#  'CANTORA MARIAH - 33330',
#  'JAMYLLE MARTINS - 50505',
#  'TARCILA RABELO - 65192',
#  'DÉBORA CAMILO - 50500',
#  'ERIKA SURUAGY - 13013',
#  'DR LEONARDA ANDRADE - 33900',
#  'MICHELA DIAS - 18050',
#  'ELEANDRA PACHUKI - 13428',
#  'ELIETH LOPES - 40231',
#  'ANGELINA - 33800',
#  'ANDRESSA CARLA - 33367',
#  'POLI DA SAÚDE - 40233',
#  'SOL DO PDT - 12069',
#  'AMANDA BISPO - 80123',
#  'ELENEIDE TEIXEIRA - 33277',
#  'ELKE DUTRA - 12121',
#  'SUZY ANNE LIMA - 40011',
#  'NAZARÉ DO TACACÁ - 33123',
#  'IARACI DIAS - 18018',
#  'PROF. JOCELY - 40240',
#  'LILIANE DOS SEM TETO - 50130',
#  'CARMEM LUCIA - 65077',
#  'GLÓRIA RIQUEZA A ABELHINHA - 43767',
#  'GISELE CASARIN - 33334',
#  'ANA DA MURIBECA - 12350',
#  'LUIZA MELO - 21021',
#  'PROFESSORA ELIZABETH - 50666',
#  'JACI - 43233',
#  'ANA LAGE - 12000',
#  'CRISTIANE SALES - 13131',
#  'PATYYS CAKES - 12200',
#  'LIZETE CONTIN - 40007',
#  'PROFESSORA MARIA LAURA - 12321',
#  'CACIKA IRÊ - 65234',
#  'VERA VERNAIDE - 13613',
#  'WANESSA BELTRÃO - 13444',
#  'MONICA DO MOVIMENTO PRETAS - 50900',
#  'LUCIANA MOREIRA - 40700',
#  'CIDA RAMOS - 13400',
#  'MARA DE QUILOMBO - 50180',
#  'YARITZA - 50069',
#  'HARUMI SATO - 33100',
#  'CLAIR OLIVEIRA - 40555',
#  'MARIANA CONTI - 50100',
#  'JANETE DE SÁ - 40800',
#  'LU DO ROSANA - 23001',
#  'SIMONE LIMA - 40888',
#  'SOLANGE BORGES - 40355',
#  'KATIA GAIVOTO - 40000',
#  'MARLI DO NASCIMENTO - 40111',
#  'MARIA TEREZA TÊ - 13275',
#  'ANARU MARTINS - 33300',
#  'DRA. KEZIA TAVARES - 50333',
#  'VALÉRIA MORATO - 65123',
#  'NILDA DA ASSOCIAÇÃO - 40111',
#  'PASTORA RAY - 33126',
#  'MILLENE SANTOS - 33150',
#  'VIVIANE - 13300',
#  'LUCIANA GENRO - 50000',
#  'MARIA MENDONÇA - 12222',
#  'TETEL DO POVO - 12123',
#  'DRA TALITA BARBOSA - 12077',
#  'PAOLLA MIGUEL - 13199',
#  'NEIDE DO LABORATÓRIO - 43999',
#  'ANA PAULA SIQUEIRA - 18444',
#  'ANGELA DA SAÚDE - 13999',
#  'LIS MARQUES - 33044',
#  'SELMINHA MARCELO - 43111',
#  'MEIRE DO LANCHE - 40500',
#  'CRIS DO PRIMAVERA - 40048',
#  'LIA GOMES - 12345',
#  'SANDRA FRASSON - 43122',
#  'LETÍCIA SANTIAGO - 12012',
#  'DANY ADEODATO - 12007',
#  'ANDREA ROSENO - 12019',
#  'ISABEL GUIMARÃES - 40272',
#  'ROSARIA NASCIMENTO - 13010',
#  'LÍVIA DUARTE - 50123',
#  'GIOVANNA ALMEIDA - 80000',
#  'ALEXANDRA - 65123',
#  'LEKA DA LOGÍSTICA - 33323',
#  'CHIRLEY PANKARÁ - 50522',
#  'MICHELE VICTÓRIO - 40165',
#  'PROFESSORA JANETE - 40500',
#  'POLLYANA DIAS - 40222',
#  'DRA JANETE RODRIGUES - 23777',
#  'MARINA CABELEREIRA - 13555',
#  'LENINHA GOMES - 40017',
#  'AS MARAJOARAS ROSE FRANCIS LAU - 40013',
#  'EDNA SAMPAIO - 13131',
#  'CIÇA MÜLLER - 12100',
#  'NAANY BARBOSA - 40013',
#  'ÍRACEMA DO PINHEIRINHO - 40217',
#  'JUSSARA FERNANDES - 12600',
#  'ANDREIA DE LIMA - 13132',
#  'PROFESSORA CÁSSIA - 65111',
#  'SUZETE GUERREIRA - 40566',
#  'PROF.. MARIA JOSÉ - 40155',
#  'JANDYRA UEHARA - 13654',
#  'ANA MARIA - 33033',
#  'MARIA LETICIA - 43000',
#  'STHEFANIE CAMIE - 12008',
#  'BÁRBARA PASTANA - 50024',
#  'BETH SAHÃO - 13456',
#  'NUBIA SALVI - 43444',
#  'MÁRCIA DA ONG - 18200',
#  'LINS ROBALO - 13444',
#  'ARLI PEDREIRA - 33200',
#  'ALINE GONÇALVES - 23231',
#  'ANNE MAMEDES - 12312',
#  'CORCINA FRANCISCO DA COSTA - 29029',
#  'TÂNIA RAMOS - 50777',
#  'MIRIAM ALGARRA - 13360',
#  'ELIEGE DOS SANTOS - 12006',
#  'SÔNIA SANTOS - 18003',
#  'CIDA BUZETTI - 12111',
#  'MARCIA LUCAS - 13413',
#  'PRISCILLA JUNTAS - 50400',
#  'THALINY - 12123',
#  'ROSALINA - 13122',
#  'CLAUDETE SILVA TEODORO - 18450',
#  'EVA NASSAR - 40200',
#  'LUCILA MARTINS - 29129',
#  'EDINEIDE MEDEIROS - 13789',
#  'VERINHA - 18306',
#  'GRAZI SILVA - 18007',
#  'LILIANE - 13100',
#  'EKEDJI LÚ FERREIRA - 12508',
#  'GISLAINE CAVALCANTE - 43777',
#  'ANA CAROLINA SERRA - 23023',
#  'BRUNA RODRIGUES - 65651',
#  'ROSINHA VIEIRA - 40456',
#  'CARMINHA SAUDE - 33159',
#  'MÁRCIA BAIANA - 23360',
#  'MEIRINHA MACUXI - 50444',
#  'DUDA LUIZELLI - 23010',
#  'VAL ELOY - 50123',
#  'MARIA EUNICE - 40444',
#  'ZULEIDE QUEIROZ - 50444',
#  'TENENTE MILENE - 33789',
#  'GABRIELA RAIA - 50000',
#  'MARILLAC LIMA - 12330',
#  'GABRIELA ORTIZ - 12132',
#  'DENISE CARVALHO - 43301',
#  'ANDRESSA LIMA - 43888',
#  'ISA ROSA - 12600',
#  'EVA VALÉRIA LORENZATO - 13123',
#  'CLÁUDIA GUERRA - 12123',
#  'ANNE MORAIS - 33333',
#  'GRETE COVER A PAULINA - 33199',
#  'MARIA BERTOCHE - 50021',
#  'GEVA FERRO - 18520',
#  'ALESSANDRA SABINO - 12789',
#  'ROSANE LOPES - 40110',
#  'PAULA SOTERO - 33210',
#  'PAULA RAMOS - 12077',
#  'AMANDA SOUZA - 50444',
#  'MARLI PAIXÃO - 40130',
#  'LAURA LEVENTI - 40555',
#  'ALEXSANDRA - 50777',
#  'MÃE ANDREIA DA DIVERSAS - 50300',
#  'EDILMA SILVA - 18270',
#  'ISIS PAQUITA - 40033',
#  'IRMÃ FRANCISCA - 23888',
#  'MARINEIDE - 13333',
#  'LURDINHA DO POVO - 23345',
#  'PSICOLOGA DEBORAH PACHECO - 23456',
#  'TERESINHA DANTAS - 13456',
#  'REJY CARVALHO - 13333',
#  'GIOVANNA SILVEIRA - 50500',
#  'JÉSSICA MICHELS - 50180',
#  'DILMA ARRAES - 13888',
#  'MARIA DA GRAÇA - 18333',
#  'TAINA ALVES - 12345',
#  'SOFIA CAVEDON - 13400',
#  'DINÁ FREITAS - 50333',
#  'ZELIZE - 50420',
#  'MARINA HELOU - 18000',
#  'NANCY IBANEZ - 12777',
#  'REGINA CÉLIA E PCDS DO PSOL - 50033',
#  'ZILDA HELENA - 13666',
#  'ADRIANA DE ALENCAR - 12302',
#  'MAH ARAUJO - 12037',
#  'GILMA GERMANO - 40789',
#  'INGRID OLIVEIRA - 18888',
#  'DUDA HIDALGO - 13180',
#  'MÃE VANDA - 13600',
#  'KERLY FERRO - 50003',
#  'PRETA - 13181',
#  'FATIMA NUNES - 13567',
#  'FRAN HIPOLITO - 12457',
#  'MARINA SANTANNA - 13000',
#  'GIL DE NEÓPOLIS - 33300',
#  'ALDETE BORGES - 12800',
#  'LAIS SANTOS - 50000',
#  'DANIELLA - 40258',
#  'WELLYDA BASTOS - 12444',
#  'ELVIRA PIRES - 33600',
#  'LUDIMILLA TEIXEIRA - 50580',
#  'ERICA TUR - 33330',
#  'JOSI DO SINDICATO - 13690',
#  'ELISIA RANGEL - 12012',
#  'DAY A FRANGA - 12347',
#  'CIDA SANTIAGO - 13580',
#  'MAYRA KARVAT - 50587',
#  'FABI MEDRADO - 21100',
#  'YASMIN GRANGEIRO - 50099',
#  'NEUDES BANCADA TRABALHISTA - 12212',
#  'JANAINA NAZARETH - 12224',
#  'COSETE CAMARA - 40707',
#  'MARIA VAI COM AS OUTRAS - 13444',
#  'OLIVIA SANTANA - 65500',
#  'PATRÍCIA RAMALHO - 12190',
#  'DRA MARIA AMÉLIA - 33300',
#  'OBREIRA LENE LOBO - 23223',
#  'ADRIANA SUL SANTANA - 50500',
#  'SHIRLEI MOURA - 40665',
#  'ELIANA DA ACADEPOL - 40600',
#  'CATERINE NOGUEIRA - 23789',
#  'MANDI MULHERES EM REBELDIA - 16123',
#  'TIA LENE - 33776',
#  'SIMONE SCHUCHANOF - 33646',
#  'SIMPLESMENTE EVA - 12415',
#  'MARA ESMERALDO - 12220',
#  'DRA. ANGELITA BOLZAN - 40153',
#  'SÍLVIA BITTENCOURT - 40656',
#  'WAL - 65654',
#  'JÉSSICA SANTOS - 13418',
#  'DELEGADA MARIA NYSA - 13144',
#  'RAQUEL DA OTICA - 33763',
#  'LUCÉLIA LIMA - 12888',
#  'THEREZINHA VERGNA - 18900',
#  'PETRUSKA DA SEGURANÇA - 40000',
#  'ANTÔNIA DO LANCHE - 12888',
#  'KATIA DUARTE - 13799',
#  'ESTELINHA DO CIEP - 12008',
#  'ODILZA PRETA - 43300',
#  'LU DO ARTESANTO - 33044',
#  'EDNA TANCREDO NEVES - 33156',
#  'KADJA RUTE - 50123',
#  'PROFESSORA CLEMILDA - 18345',
#  'LARISSA MARCA - 40045',
#  'GOVINDA DA LIMPEZA - 40231',
#  'FLOR DA COLETIVA - 65100',
#  'DEJANIRA TARZAN - 12612',
#  'PEPE - 18155',
#  'CELOIR GUEDES - 12610',
#  'CLAUDIA MONTANARI - 50001',
#  'ENFERMEIRA IRENE - 12612',
#  'SUZANA CARVALHO - 43010',
#  'ANA CRISTINA - 18018',
#  'LUCÉLIA QUARESMA - 13134',
#  'IZABEL CRISTINA - 33888',
#  'KARLA MONTALVÃO - 33644',
#  'MARIANGELA BANDEIRA - 12120',
#  'ALZIRA RODRIGUES - 33230',
#  'CELIA SILVA - 12380',
#  'FAFÁ CRIANÇA FELIZ - 33444',
#  'LUCINHA DO MST - 13100',
#  'CLEUDA SOUZA  - 33103',
#  'FEIRANTE NEGONA - 13814',
#  'JANE SANTOS - 18168',
#  'VIÚVA LEANDRA - 33333',
#  'PAULA FILZEK - 12121',
#  'CAROLINA CACAU - 16555',
#  'DELEGADA MARTHA ROCHA - 12040',
#  'TIA ADELAIDE - 65100',
#  'SUZI RODRIGUES - 13000',
#  'DRA KELLY BATISTA - 40012',
#  'TIA HILDA MACAMBIRA - 33225',
#  'STEFANI - 40200',
#  'TALITA CADEIRANTE - 40012',
#  'JÔ OLIVEIRA - 65000',
#  'SANDRA SUELI - 23385',
#  'SIDILENE LIMA - 13133',
#  'NILMARA LEAL - 33312',
#  'DORA SOUZA - 33277',
#  'MAÍSA PAIVA - 12012',
#  'ROSANGELA PENICHE - 12010',
#  'PAMELA DO SOCIAL - 33006',
#  'DEBORA CRISTINA - 50252',
#  'BIA DESIGNER - 12999',
#  'VANESSA MIRANDA - 18100',
#  'MAVETE - 40444',
#  'DONA ANA DO AMBULATÓRIO - 23707',
#  'PROFESSORA ANA - 12666',
#  'SOLANGE THEODORO - 12001',
#  'CLAUDIA LELIS - 43123',
#  'YARA FERRY - 16161',
#  'GALEGA DA BANCA - 33999',
#  'VALDENIRIA - 40123',
#  'BIANCA QUILOMBOLA - 18333',
#  'LIGIA MENDES - 80000',
#  'JULIANA MITTELBACH - 13257',
#  'SOSSÔ STANSK - 40012',
#  'MÁRCIA HASSE - 43333',
#  'LUCIANE MATTEUSSI - 23223',
#  'CABO INGRID - 40190',
#  'PROFESSORA JULIA SILVEIRA - 50555',
#  'SIMONE KARIPUNA - 43222',
#  'LIZ DE QUEIROZ - 13456',
#  'ROSANGELA BRITO - 33722',
#  'ADRIANE QUILOMBOLA - 13789',
#  'MARLENE PASSOS - 40773',
#  'PROF ISABEL CRUZ - 50890',
#  'ZETY ARAUJO - 18456',
#  'CRIS PSICÓLOGA - 18607',
#  'CARMEN SENTO SE - 12162',
#  'JÔ MORAES - 65656',
#  'MARLEIDE CUNHA - 13333',
#  'ANDREIA DE JESUS - 13050',
#  'MILENA FEITOSA - 13789',
#  'ANA LAURA NEVES - 12100',
#  'EULINA COUTINHO  - 16066',
#  'ELIENNE BAPTISTA - 40489',
#  'JOSI ADHUMA: VAI TER PRETA SIM - 50606',
#  'IVANIA - 65100',
#  'ALEXANDRA DEERING - 12004',
#  'GORDA DE BRITTO - 40456',
#  'LINDA BRASIL - 50180',
#  'VÂNIA COLETIVO CAMINHOS - 50074',
#  'WILMA ROCHA - 18770',
#  'DIVA - 13234',
#  'ELIANE BANDEIRA - 13113',
#  'MAGALI RABELLO - 12340',
#  'PROFESSORA ANDREINA - 12198',
#  'DRA SANDRA ROCHA - 33666',
#  'MARCIA QUINTANILHA - 65656',
#  'JIO SOARES - 40258',
#  'ENFERMEIRA ANA RODILÂNDIA - 40070',
#  'ANDREIA TOLENTINO - 40278',
#  'PROFESSORA EDITE ANDRADE - 18522',
#  'RENATA SOUZA - 50007',
#  'JÉSSICA SILVA - 65111',
#  'PROFESSORA FATIMA - 13789',
#  'REGINA DO SALÃO - 40234',
#  'CARINA VITRAL - 65180',
#  'PROFA. VANDA ROCHA - 65651',
#  'DANI CARNEIRO - 40049',
#  'DAIANA LEILA - 12400',
#  'SONIA HOLISTICA - 50110',
#  'ESTER FERREIRA - 40222',
#  'CANTORA JANAINA LIMA - 50100',
#  'SOANE GALVÃO - 40123',
#  'ELZA FORTES - 12600',
#  'LILIANE RODRIGUES - 50000',
#  'YARA - 13155',
#  'LUDIMILA DA MANDATA COLETIVA - 50555',
#  'JOICE SOUZA - 50200',
#  'SIMONE BRITO - 18678',
#  'NAYRA NOGUEIRA - 43222',
#  'VÂNIA GOMES - 80180',
#  'VERONICA - 12443',
#  'KAKÁ BEZERRA - 18188',
#  'RAINY - 40400',
#  'OLGA MACUXI - 23111',
#  'ALE BEZERRA - 12100',
#  'CAROL GOMES - 23123',
#  'ALE VECCHIO - 33133',
#  'TIA DO CAFÉ - 40656',
#  'ADRIANA SOUZA - 13000',
#  'DANI RABELO - 12013',
#  'ODALEIDE CARVALHO - 43321',
#  'MÔNICA ARMADA - 13135',
#  'COLETIVO_ ENFERMAGEM_ALAYNA - 12444',
#  'DIVANEIDE - 13613',
#  'ROSANA SAWAKI - 12444',
#  'MARIA PERPETUO - 50033',
#  'JULIANA HELMER DO PT - 13123',
#  'ROSANA SILVA - 33962',
#  'CLAUDINHA - 65651',
#  'LANA RODRIGUES - 40198',
#  'LETICIA BASILIO - 33777',
#  'PROFESSORA BARTÔ - 13222',
#  'SILVANIA VASCONCELOS - 12012',
#  'DEBORA DE ALMEIDA - 33737',
#  'ROSELANE ARAUJO - 40040',
#  'MANDATO COLETIVO MARIZA - 33120',
#  'IVONETE CARVALHO - 13677',
#  'MARIA RUTHE - 23008',
#  'ELAINE FERREIRA - 40440',
#  'ELIZABETE - 23233',
#  'ROBERTA CAVALCANTE - 12444',
#  'EVA MÁRCIA - 13130',
#  'CLEANE RAMALHO - 12755',
#  'KELE CRISTINA - 33002',
#  'ANGELA MACHADO - 12212',
#  'GISA BRAZ - 12222',
#  'IZABEL CAMPOS - 50023',
#  'TATIANE ABDALA - 40888',
#  'JÔ FARIAS - 13258',
#  'ENFERMEIRA JOANA PAZ - 43090',
#  'DRA. NEILA AZRAK - 43555',
#  'SUELI ESTEVES - 12129',
#  'DANI RODRIGUEIRO - 12012',
#  'THÍFANY FÉLIX - 18181',
#  'JOANEYDE DO SINDICATO - 40122',
#  'MYKAL - 50033',
#  'DENISE VIEIRA - 23637',
#  'THAÍSE PACHECO - 13333',
#  'DR KARLENE - 23333',
#  'PROFESSORA LÉO SIMÃO - 13789',
#  'NEGA VAN PSOL - 50777',
#  'THAWANNA - 18180',
#  'ERIAN OZÓRIO COLETIVAS - 18777',
#  'JOSI É NOIS A MUDANÇA  - 50055',
#  'CIDA FREIRE - 12190',
#  'PROFESSORA EVELYN - 12900',
#  'CRIS ALVES RAINHA - 12529',
#  'ROSE DO TRADIÇÃO - 40888',
#  'TAIS SOUZA - 33777',
#  'ELAINE CHAVES - 12777',
#  'TELMA NERY - 23000',
#  'MARTA FREITAS - 43123',
#  'ANA PERUGINI - 13121',
#  'PERITA LECOQ - 12569',
#  'DAIONARA ANDRADE - 50456',
#  'LIS SALGUEIRO - 12999',
#  'TIA CÉLIA BERSAN - 12444',
#  'MARCIA LIA - 13113',
#  'MARIA HELENA - 50100',
#  'MARIA BARROSO - 12123',
#  'PAOLA REIS - 12100',
#  'MARISA ZANONI - 13031',
#  'ADRIANA ROSSI - 13777',
#  'RENATA LIMA - 50990',
#  ' THAIANE GARCIA - 40040',
#  'MÃE DAYSE - 13029',
#  'RAIMUNDA QUEIROZ - 40555',
#  'PROFA ANA CLÁUDIA - 33789',
#  'SANDRA NAVAJAS - 12021',
#  'CHARLENE PIEDADE - 18047',
#  'PÉROLA NEGRA - 40732',
#  'JAQUELINE PORTO - 50047',
#  'DANIELE FARIAS - 43211',
#  'MARIA - 13123',
#  'APÓSTOLA MIRIAM FEIJÓ - 12117',
#  'CRISTINA CARVALHO - 12312',
#  'JUCÉLIA NASCIMENTO - 12333',
#  'SIMONE GIROTO - 23500',
#  'BEEL DA SILVA - 13013',
#  'LEONORA PÉRICO - 12111',
#  'NENEKA CUNHA - 33733',
#  'JAQUELINE JJ - 13130',
#  'DORA DA SAÚDE - 65161',
#  'CAMILA PINHEIRO  - 50111',
#  'WANDERLEYA SILVA - 12401',
#  'ÁGATA MOSTARDEIRO - 13070',
#  'DORA FREITAS  - 12125',
#  'GILMARA PORTELA - 33733',
#  'VAL - 18200',
#  'SÔNIA MORAS - 65365',
#  'CLEOR SANTOS - 23002',
#  'AÇUCENA CALHEIROS - 40700',
#  'SANDRA DA PESCA - 40033',
#  'VILMA E ZÉLIA - COLETIVO - 18999',
#  'MARLY CALDAS - 13600',
#  'DÉBORA MARCOLINO - 13333',
#  'TELMA MARIA - 33313',
#  'INÊS MARTINS - 40122',
#  'PROF ZILMA MELO - 18833',
#  'CÍCERA ISAANY - 13813',
#  'PROFESSORA MARINILDE - 18123',
#  'CIDA DO PT - 13133',
#  'VIRGINIA JUNTAS EM MOVIMENTO - 50420',
#  'RENATA EVANS - 40118',
#  'SILVINHA DUDU - 43456',
#  'MARCIA RIBEIRO - 12045',
#  'LUANA MOTA - 12180',
#  'TELMA MELLO - 50100',
#  'GISA AZAMBUJA - 12123',
#  'MARGARIDA DO JUCÃO - 12627',
#  'SANDRA OLIVEIRA - 40115',
#  'ANGELICA LIMA - 12270',
#  'VERÔNICA LIMA - 13580',
#  'ANGÉLICA DE HOLANDA - 33882',
#  'MAGNÓLIA - 12190',
#  'PROFESSORA MARIANA - 13147',
#  'EMILI FARIAS - 12321',
#  'CARLA DA SAÚDE - 23070',
#  'SONILCE SANTOS - 50127',
#  'PROFESSORA JOSELI CAVALHEIRO - 40445',
#  'JOSELIA SILVA - 33800',
#  'IRMA LÚCIA DO EITEL - 40999',
#  'CIDA MULHERES DE TODAS LUTAS - 50150',
#  'LEONICE TOLENTINO - 33789',
#  'MARTINHA - A SAÚDE RESISTE - 23192',
#  'ELIZANGELA PIRES - 13190',
#  'CLAUDIA COUTINHO - 12345',
#  'MARTA - 18010',
#  'CANTORA ALECIANE - 50150',
#  'SUELY GUILHERME - 13100',
#  'PROTETORA PATRÍCIA VARGAS - 50100',
#  'LUCIENE DA TV - 33123',
#  'LENINHA - 13456',
#  'MARCIA LIMA - 23423',
#  'JOELMA LOPES - 50800',
#  'SILVANA RODRIGUES - 40110',
#  'LÍVIA LIRA - 18300',
#  'NAYLA - 12180',
#  'ANGÉLICA - 13331',
#  'SOLANDIA COELHO - 33888',
#  'MADALENA DANI TODAS AS VOZES - 50777',
#  'ROBERIA PINCHO - 33166',
#  'PROFESSORA CLARICE - 13813',
#  'SAM E LOBO BOM - 40999',
#  'PAULA DA BANCADA FEMINISTA - 50000',
#  'FLÁVIA DINIZ AFROPCD - 13131',
#  'VANESSA ORTIZ - 13900',
#  'LILA DE SOUSA - 12126',
#  'ELIANE RAMOS - 40282',
#  'ELIANE ALVES - 40013',
#  'ADRIANA GOMES - 12033',
#  'ENFERMEIRA SIEPIERSKI CALIMAN - 12002',
#  'PROFESSORA NILSE - 12345',
#  'TATY - 40020',
#  'ITAMARA SOUZA - 43123',
#  'CAMILA PRETA - 12220',
#  'BELLA GONÇALVES - 50500',
#  'RISLAYNE SOUZA - 12321',
#  'PROFESSORA DENIZA SOUZA - 23222',
#  'SANDRA RIBEIRO - 43606',
#  'ANA CLEIA KIKA - 13300',
#  'PROFESSORA CRIS NOGUEIRA - 40043',
#  'PROF RITA - 18000',
#  'ISABEL DINIZ COLETIVO POPULAR - 13300',
#  'GISLAINE DURSKI - 13113',
#  'JACIARA XAVIER - 18555',
#  'ADRIELE - 12569',
#  'RITA MANGANGA - 18018',
#  'LUCIANA DO NASCIMENTO - 12445',
#  'LILIAN DINIZ - 18199',
#  'PATRÍCIA MELO - 13180',
#  'ANGELA MARIA - 33900',
#  'RENATA FALZONI - 40400',
#  'KÁTIA - 13013',
#  'RAYANE ANDRADE - 13111',
#  'NILSA DO PT - 13456',
#  'JU SALVETTI - 18016',
#  'MÔNICA COLETIVO ARCO-ÍRIS - 18222',
#  'MARI LACERDA - 13131',
#  'VANDA VALADARES - 43043',
#  'EDIANE MARIA - 50110',
#  'FRANCINE CANTO - 40333',
#  'GIVALDA-COL.BEATRIZ NASCIMENTO - 13900',
#  'PROFESSORA JACI TODAS AS LUTAS - 50088',
#  'DANI PORTELA - 50000',
#  'MARCIA CARDIM - 12440',
#  'SUSY SEVEN - 40717',
#  'MARIANA MOURA - 65300',
#  'THAY ARAÚJO - 13800',
#  'BIA NOBREGA - 43437',
#  'CRIS DEL PINO - 33456',
#  'KATIA DA SAÚDE - 40000',
#  'NIVALDA CARDOSO - 43433',
#  'JULIANA LUCENA - 13555',
#  'GABI SABINO - 40222',
#  'CIDA FALABELLA - 50018',
#  'VALÉRIA JÁCOME - 23777',
#  'JARDIMIRA SÁ - 12612',
#  'SILVINHA DAS PADARIAS - 23245',
#  'CAMILA OLIVEIRA - 18800',
#  'DRA SILVIA - 40999',
#  'CAMILA TAPIA - 40404',
#  'THAÍS TOLENTINO - 50555',
#  'MARUSKA MAGALHAES - 12999',
#  'BEL LIMA - 18004',
#  'ELISA - 21210',
#  'KIKA DA SERRA - 12344',
#  'BISPA VALDINEIA BISPO - 40237',
#  'MAYARA TORRES - 40040',
#  'KEIT LIMA - 50300',
#  'MARINA DO MST - 13713',
#  'DRA TAÍS MATOS - 65000',
#  'LARISSA STEPHANIE - 65180',
#  'PROFESSORA MIRANDA - 50027',
#  'CAROLLINE SARDÁ - 50100',
#  'DRA. GRAZI - 40500',
#  'REGINA LINS DA MUNDIAL - 13777',
#  'CHEILA OLALLA - 13400',
#  'ADRIANA GERONIMO - 50777',
#  'EUDIANE MACEDO - 43666',
#  'RITA LINS - 13603',
#  'JANAÍNA GUERREIRA - 12130',
#  'PROFESSORA BETH - 13113',
#  'NUBIA DO HERMES - 43777',
#  'JANETE PIETÁ - 13877',
#  'JACKELINE ROCHA - 50222',
#  'PRETA KAROL - 13138',
#  'PROFESSORA JUSSARA - 13123',
#  'TATI RIBEIRO - 50123',
#  'HELAINE COELHO - 12127',
#  'FLOR PINHEIRO - 40537',
#  'IRMÃ MARA LÚCIA - 23400',
#  'BERNARDA THAILANIA - 50008',
#  'MEIRE MORAIS - 40212',
#  'BERNADETE  - 50322',
#  'SAMIA A VERAS - 23577',
#  'PROF. CHRIS GRACE - 13696',
#  'ROSE CIPRIANO COLET.PERIFÉRICA - 50800',
#  'COMADRE GUERREIRA - 18000',
#  'BETH NORONHA - 43555',
#  'ELIENES FERNANDES - 18013',
#  'CÁTIA MACHADO - 50014',
#  'TALLIA SOBRAL - 50000',
#  'VANESSA FACUNDES - 12121',
#  'CLEONICE GONÇALVES - 12077',
#  'FABY GOMEZ - 50570',
#  'ELZUILA CALISTO - 13999',
#  'FABIANNI NUNES - 12344',
#  'PROFA. IRIS AMÂNCIO - 43888',
#  'JADE LEÃO - 13310',
#  'ELIZABETH GALDINO - 12400',
#  'FLÁVIAH RODDRIGUES - 12101',
#  'ÌYÁ SANDRALI - 13777',
#  'EDINALDA CUIDADORA - 18321',
#  'DILMA OLIVEIRA DA AVIAÇÃO - 40999',
#  'CRISTINA OLIVEIRA - 12355',
#  'FABIANA SCHREINER - 43222',
#  'LIVIA - COLETIVA RAÍZES - 50222',
#  'CACÁ D ARCADIA - 13184',
#  'KAROL TARTAS - 43007',
#  'PROFESSORA CAREN MACHADO - 40999',
#  'KATIA GOMES - 33019',
#  'CRISTINA GONÇALVES - 40044',
#  'TEREZINHA DE JESUS - 33987',
#  'MÃE LIGIA - 13131',
#  'MARINA COLETIVO MANTIQUEIRA - 18001',
#  'MARI VIANA - 50056',
#  'DELEGADA CARLA BRITTO - 12777',
#  'TATIANA PIRES - 40100',
#  'CRISTIANE LACERDA - 50333',
#  'IYÁ FERNANDA DE MORAES - 40412',
#  'ESTELA ALMAGRO - 13258',
#  'PROFESSORA RAILDA - 50888',
#  'NEIA COSTA - 12002',
#  'JORGETÂNIA - 50130',
#  'BENNY BRIOLLY - 50555',
#  'TICIANA PRESTE - 40121',
#  'CAMILA VALADAO - 50180',
#  'ANA MARIA DA SAÚDE - 50503',
#  'BETÂNIA ALMEIDA - 43200',
#  'DRA. ANDRESSA COSTA - 40525',
#  'PROFESSORA ÉBNER - 43123',
#  'EVA SANTOS - 18018',
#  'NAZARÉ BANCADA MANAS DE LUTA - 13313',
#  'KEILA CERQUEIRA A SINDICA - 23777',
#  'PRISCILA DOURADO - 40333',
#  'BRUNA MULHERES POR + DIREITOS - 50321',
#  'SANDRA POTIHER - 12555',
#  'VALENTINA A VOZ DO SUBÚRBIO - 13008',
#  'RHILARY BECKER - 40012',
#  'MONICA ALVES - 50010',
#  'AURIMAR LIMA - 18777',
#  'MONICA TAVARES - 18180',
#  'DRA SALMA - 12121',
#  'ROSE MARTINS - 12567',
#  'PROFESSORA NÚBIA - 40500',
#  'POLLY DO AMARAL - 50010',
#  'ANDREIA RIBEIRO - 50199',
#  'KÊNIA RIBEIRO - 50444',
#  'ZÉLIA DO JOÃO SAPATEIRO - 23444',
#  'CRICIELLE - 13333',
#  'OLINDA CAETANO - 18111',
#  'PROFESSORA DIANA DE CASSIA - 16161',
#  'CÁTINA MONTEIRO - 12912',
#  'IRINY LOPES - 13133',
#  'UILIA DOS SANTOS - 33999',
#  'ROSA - 33322',
#  'ELAINE PRETAS JUNTAS - 50420',
#  'LENNE CASTRO - 33775',
#  'NATHÁLIA MOZER - 21021',
#  'MARCIA FUMAGALLI - 40300',
#  'REJANE CONEXÃO - 43333',
#  'AUDREY SNOOPY - 18101',
#  'JOANA D ARC - 12000',
#  'DOUTORA ZEILDA - 12349',
#  'LUNA ARAÚJO - 50100',
#  'VERONICA SANTIAGO - 40021',
#  'BRUNA RIQUELME COLETIVO - 12222',
#  'LENE REIS - 40622',
#  'DENNYS - 50555',
#  'PROF CIDACARLOS ELASCOM O POVO - 13545',
#  'GIORGIA PRATES - MANDATA PRETA - 13130',
#  'KELLYN ARAUJO - 12000',
#  'ANDREA JENEFFER - 50123',
#  'PASTORA NERACI - 33022',
#  'PAULLA ROSA - 12357',
#  'DIDA COLETIVO EM TODAS LUTAS - 50013',
#  'VALDEISA FIGUEIREDO - 33400',
#  'CONCEICAO GOMES - 33123',
#  'GABY DUARTHE - 33017',
#  'BIA DE LIMA - 13123',
#  'IZAURINHA - 50250',
#  'CLAUDIA DIAS - 12321',
#  'ISABELLE DIAS - 40555',
#  'CLÁUDIA ROMA - 43456',
#  'MILENA REIS - 18777',
#  'ADRIELLI PRESTES FILHA DO DEDÉ - 23777',
#  'CRIS FURTADO - 40040',
#  'ROSE RIBEIRO - 23479',
#  'MARIANA LACERDA - 18018',
#  'RENE ROCHA - 43912',
#  'KEILA PEREIRA - 65400',
#  'FERNANDA BISKUP - 23456',
#  'SILVANETE REI DO GADO - 50456',
#  'MÃE LÚCIA - 40120',
#  'THAINARA FARIA - 13016',
#  'DANI BALBI - 65123',
#  'SILVANETE DE BRITO - 50777',
#  'THIELLE FERRARI - 33187',
#  'PASTORA VANDERNA - 18881',
#  'ANDRÉA GONÇALVES - 40777',
#  'ROZANA BARROSO POVO NO PODER - 65013',
#  'DORA EXEVERRIA - 40013',
#  'DANI MONTEIRO - 50050',
#  'LUCIANA DE TINGUÁ - 23444',
#  'JOSI DA RADIO - 40777',
#  'NICE - 18777',
#  'AUGUSTA BUFFOLO - 40369',
#  'DEIA ZULU AFROFUTURISTA - 13500',
#  'PROFA FRAN - 40321',
#  'PÊPE DE ITAOCA - 23062',
#  'PROFESSORA ÉRIKA CÂNDIDO - 50010',
#  'JANAINA ALMEIDA - 40225',
#  'SILVIA DE MENDONÇA - 13777',
#  'CREUZAMAR - 13000',
#  'ANDREIA DAMACENO - 12973',
#  'MARIA DA CONSOLAÇÃO - 50888',
#  'FÁTIMA OLIVEIRA - 18333',
#  'MÔNICA DINIZ - 50999',
#  'NATALIA LÚCIA - 80180',
#  'JACK MEIRA - 50200',
#  'LUZIENE QUEIROZ - 12336',
#  'MARISA METROVIÁRIA - 16016',
#  'LETICIA FLORÊNCIO - 13613',
#  'VANESSA FELIPPE - 12800',
#  'MARIÂNGELA MARINH - 33332',
#  'ENFERMEIRA DART CLAIR - 65065',
#  'LARISSA FERNANDA - 50180',
#  'KARLA MARTINS - 40400',
#  'CRIS BANCADA EDUCAÇÃO E LUTA - 16100',
#  'CARMEM AMÉRICO - 18001',
#  'DÉBORA FIRMO - 50999',
#  'ANE EBRAHIM - 23333',
#  'KÁTIA DO BENGUÍ - 12600',
#  'ELIANE XUNAKALO - 13456',
#  'JEANE SOUZA - 50555',
#  'BARBARAH BRASIL - 40106',
#  'DANI COLETIVO JUVENTUDE - 13013',
#  'CARLITA SOUZA - 40003',
#  'THALISSA FLEXA - 40101',
#  'CRISTINA COSTA - 13688',
#  'CRISTIANE DE DEUS - 12512',
#  'MAGNOLIA LAGO - 13500',
#  'MARY - 40222',
#  'KEULEN BARROS - 40444',
#  'ENFERMEIRA FERNANDA - 12125',
#  'PROFESSORA ANA CRISTINA - 65777',
#  'GABI SALERNO - 12121',
#  'PROFESSORA RITA DELLA GIUSTINA - 13213',
#  'FERNANDA COLETIVO MÃOS DADAS - 12006',
#  'ANA MIELKE - 50075',
#  'TATIANA LABAREDA - 33789',
#  'LÉIA - 40700',
#  'DR. JANINE - 23222',
#  'JÔ DO VIVER MELHOR - 40092',
#  'LUZIA ARAUJO - 33111',
#  'THALITA TAVARES - 50180',
#  'CIDA ALVES - 65789',
#  'LUCIANA AMARAL - 43000',
#  'CLAUDINHA LOPES - 40433',
#  'JOANICE RIOS - 50507',
#  'MARCIENE DA COSTA - 40013',
#  'LARA LUÍSA - 12222',
#  'TEREZINHA BERTINI - 23135',
#  'SUELI COSTA ROSA - 23780',
#  'GIANE E COLETIVO PROTETORES - 40400',
#  'AMÁLIA SANTANA - 13613',
#  'CHANNANDRA PIRES - 40789',
#  'PATRÍCIA CRIZANTO - 40234',
#  'PROFA SUZETE UNIDAS NA LUTA - 50222',
#  'SANDRA - 33789',
#  'DEISE COUTRIM - 33650',
#  'NEUSA CADORE - 13690',
#  'GISELE DA SAÚDE - 13192',
#  'EDNA DO GÁS - 13023',
#  'ELIDA MIRANDA - 13500',
#  'DRA. CALU - COLETIVA PLURAL - 13513',
#  'TEREZA ARAPIUM - 18188',
#  'DENISIA RIBEIRO - 12021',
#  'NEGRA MAGNA - 50345',
#  'FLÁVIA HELLEN - 13180',
#  'MARIA ALICE - 23600',
#  'CIRLETE QUEIROZ - 50245',
#  'NEON CUNHA - 50700',
#  'ADRIANA ENFERMEIRA - 40300',
#  'ADRIANA FRAZÃO - 33300',
#  'CICLEA - 40090',
#  'LUCILENE KALUNGA - 40100',
#  'PROFESSORA DOTE - 12111',
#  'SANDRA SULINO - 12321',
#  'CARLA MACHADO - 13321',
#  'CHANTAL - 80180',
#  'PROFESSORA NATALIA GUARINO - 12200',
#  'PROF ANGELA AFONSINA - 50112',
#  'DRA. VALDILENE - 23180',
#  'CLAUDIA DO ALIMENTA SP - 43000',
#  'LAURA DO MARABAIXO - 43174',
#  'LUCIANA SANTOS - 23231',
#  'LISETE NEVES - 40457',
#  'ROZANGELA DO SOCORRO DE LIMA - 40040',
#  'VANDA PINEDO NOSSA FORÇA E VOZ - 13913',
#  'PROFA UZIELITA - 40156',
#  'DORA AMARAL - 12111',
#  'DR. MICHELLE MELO - 12555',
#  'RAQUEL TOIAN ADVOGADA - 33422',
#  'AVELIN KAMBIWÁ - 12626',
#  'SANDRA HELENA DO POSTINHO - 12054',
#  'LUCIANA LIMA - 16123',
#  'EUNICE MELO - 23323',
#  'PATRÍCIA RAMOS - 16166',
#  'ZENAIDE DA LUZ - 40021',
#  'CRISTIANE AQUINO - 12888',
#  'LUARA DO AXÉ - 12180',
#  'MOARA SABOIA - 13600',
#  'DR. THAIZA - 12111',
#  'MARCIA SANTOS - 12099',
#  'NEIVA LAZZAROTTO - 50001',
#  'PRISCILA DO COLETIVO ANDIROBAL - 50070',
#  'LOHANNA - 43500',
#  'GIOVANA BARROS SINDICALISTA - 13333',
#  'STEPHANIE SOUZA - 33773',
#  'PROF. MARCIA VIEIRA - 23777',
#  'SENNA DO SOCIAL - 12777',
#  'CARMEN SILVA - 40300',
#  'NICOLE SOLLBERG - 13180',
#  'PROFESSORA TERESINHA - 13130',
#  'JESSICA CARVALHO - 12020',
#  'LUCILENE FERREIRA - 12566',
#  'LUCIANE CARMINATTI - 13601',
#  'PROFESSORA DEJANIRA - 43564',
#  'ELISÂNGELA RENASCER - 50050',
#  'SOLANGE DA SAÚDE - 50101',
#  'CARMEM LUCIA CARDOSO - 33093',
#  'TERESA BRITTO - 43333',
#  'RÔ - 12212',
#  'CRIS ESTRELA - 12789',
#  'MICHELE MARCELINO - 40707',
#  'CAROL QUINTANA - 13044',
#  'ROSE DUARTE - 13600',
#  'WELNA DRA CHUCHU - 40007',
#  'PATRICIA MENDONÇA - 12169',
#  'PROF. ZILMA - 12000',
#  'LAIS CRUZ - 40800',
#  'DEISE FRANKLIN - 40477',
#  'ALYSSANDRA GURGEL - 12112',
#  'JEANE RIBEIRO - 13222',
#  'ANTONIA ROSA - 50118',
#  'ALICE CARVALHO - 50777',
#  'PROFESSORA SAMARA - 16123',
#  'MEYRINHA - 23000',
#  'MARIANA MARQUES - 12002',
#  'MARIA DEL CARMEN - 13131',
#  'MORGANA LUNA - 43567',
#  'VILMA BATISTA - 40190',
#  'ELIANE BOMTEMPO - 33456',
#  'ELIKA TAKIMOTO - 13021',
#  'LIDIANE DAVID - 33108',
#  'LENISE LOUREIRO - 23000',
#  'LAÍS NÓS COLETIVO - 50200',
#  'DANIELA REGINA - 40400',
#  'GLEICE JANE - 13777',
#  'PATRICIA VIUVA - 40022',
#  'CAROL BERNARDELI - 43210',
#  'DORINHA ALVES - 43007',
#  'DELEGADA ROSAMALENA - 23013',
#  'LENIR RODRIGUES - 23456',
#  'LILIAN CAVALCANTE - 12200',
#  'FLORISMAR BANCADA AMAZÔNIDA - 13550',
#  'COMPANHEIRA LINDALVA - 65333',
#  'PROF HALDA AMORAS - 40044',
#  'TELMA DE SOUZA - 13004',
#  'JANA GUEDES - 12555',
#  'NICINHA DURANS - 16116',
#  'DANDARA - 13777',
#  'RENATA TENORIO DO SINDICATO - 65555',
#  'DAIANE SENA - 33300',
#  'MARIA EUGENIA BIFFI - 12016',
#  'EULINA - 50555',
#  'JUJU MANSUR - 40777',
#  'LARISSA DO COLETIVIZANDO - 65613',
#  'ZENA AMARAL - 18111',
#  'MISSIONARIA FRANCISCA - 12105',
#  'PROFESSORA JOANITA - 23614',
#  'SHAKIRA SOUZA - 12555',
#  'ALZIRA NOGUEIRA - 50123',
#  'CRISTINA DE BRIZOLA - 12014',
#  'LUANA RIBEIRO - 23123',
#  'MARLENE PROFESSORA - 40023',
#  'FERNANDA MIRANDA - 50999',
#  'CLAUDIA SACRAMENTO - 40670',
#  'MARGARIDA LOPES - 23300',
#  'LIDIANE FUNARI - 40462',
#  'MAIARA BATISTA - 12020',
#  'LILIAN BEHRING - 65656',
#  'EVELYN DO PT - 13112',
#  'IRMÃ NILDA - 40091',
#  'DETE SILVA - 65035',
#  'ARLETE FREITAS - 23444',
#  'CAROL PIRES - 18180',
#  'MARILÉA DA SAÚDE - 13888',
#  'BRENDA MANGABEIRA - 80000',
#  'MISSIONARIA ALESSANDRA - 40155',
#  'SIMONE SANTANA - 40456',
#  'FABIOLA DA RUA DA VALA - 23313',
#  'SÔNIA DAMASCENO - 40007',
#  'LILIANE ABREU - 43456',
#  'LYKA AMARIO - 33321',
#  'JANAINA DO ARENOSO - 33388',
#  'HELENA ALVES - 50222',
#  'PROFA GRACIELE - 13613',
#  ...]

# %%
candidatosDepEstadual.shape[0]
# Out:
# 14967

# %%
import ipywidgets as widgets
import pandas as pd




# data = {"label_1":"data_1", "label_2":"data_2", "label_3":"data_3"}
filtroGenero = ["DS_GENERO == 'MASCULINO'","DS_GENERO == 'FEMININO'","DS_COR_RACA == 'BRANCA'","DS_COR_RACA == 'PARDA'","DS_COR_RACA == 'PRETA'","DS_COR_RACA == 'AMARELA'","DS_COR_RACA == 'INDÍGENA'"]
filtroGeneroTitulos = ["Homem","Mulher",'Branca','Parda','Preta','Amarela','Indígena']


names = []
checkbox_objects = []
for idx,key in enumerate(filtroGenero):
    checkbox_objects.append(widgets.Checkbox(value=False, description=filtroGeneroTitulos[idx]))
    names.append(key)

arg_dict = {names[i]: checkbox for i, checkbox in enumerate(checkbox_objects)}

# ui = widgets.HBox(children=checkbox_objects)
ui = widgets.GridBox(children=checkbox_objects,layout=widgets.Layout(grid_template_columns="repeat(3, 100px)"))


widgets.GridBox(items, layout=widgets.Layout(grid_template_columns="repeat(3, 100px)"))


selected_data = []
def select_data(**kwargs):
    selected_data.clear()

    for key in kwargs:
        if kwargs[key] is True:
            selected_data.append(key)
    # print(selected_data)


    if len(selected_data) > 0: 
        selection = " | ".join(selected_data)
        candidatosDepEstadual = pd.read_csv("candidatosDepEstadual.csv")
        
        candidatosDepEstadual = candidatosDepEstadual.query(selection)
        display(candidatosDepEstadual)
#     if len(selected_data) > 0:    
#         df = df[df.Fruit==selected_data[0]]
#         display(df)
    
    
out = widgets.interactive_output(select_data, arg_dict)
display(ui, out)
# Out:
# GridBox(children=(Checkbox(value=False, description='Homem'), Checkbox(value=False, description='Mulher'), Che…
# Output()

# %%
data = [['A', 'Orange', 2],['B', 'Apple', 3],['A', 'Banana', 4]]
df = pd.DataFrame(data, columns=['Letter','Fruit','Number'])
df


ff = "Fruit == 'Orange' | Fruit == 'Banana' | Fruit == 'Apple'"
df = df.query(ff)
df
# Out:
# Empty DataFrame
# Columns: [Letter, Fruit, Number]
# Index: []

# %%
var = ["Fruit == 'Orange'","Fruit == 'Banana'","Fruit == 'Apple'" ]

var = " | ".join(var)

var

df.query(var)
# Out:
#   Letter   Fruit  Number
# 0      A  Orange       2
# 1      B   Apple       3
# 2      A  Banana       4

# %%
len(selected_data)
# Out:
# 0

# %%
selected_data
# Out:
# ['label_1', 'label_2', 'label_3']

# %%
from ipywidgets import interact
import pandas as pd

def show_df(value):
    data = [['A', 'Orange', 2],['B', 'Apple', 3],['A', 'Banana', 4]]
    df = pd.DataFrame(data, columns=['Letter','Fruit','Number'])
    print(df[df.Fruit==value])

interact(show_df, value = ['Apple','Orange'])
# Out:
# interactive(children=(Dropdown(description='value', options=('Apple', 'Orange'), value='Apple'), Output()), _d…
# <function __main__.show_df(value)>

# %% [markdown]
# # candidatos a deputado estadual!

# %%
candidatosDepEstadual = pd.read_csv("candidatosDepEstadual.csv")
candidatosDepEstadual
# Out:
#        NM_URNA_CANDIDATO SG_PARTIDO IDEOLOGIA_PARTIDO SG_UF  DS_GENERO  \
# 0            LUIZA DULCI         PT          Esquerda    MG   FEMININO
# 1           ROSELI BRITO       REDE          Esquerda    RJ   FEMININO
# 2          GRACIELE LIMA    PC do B          Esquerda    RR   FEMININO
# 3      ADERLÂNDIO FRANÇA        PDT          Esquerda    AC  MASCULINO
# 4           PRIMO RENATO   PATRIOTA           Direita    RJ  MASCULINO
# ...                  ...        ...               ...   ...        ...
# 14962     DAYANE CAMILLO  CIDADANIA          Esquerda    PR   FEMININO
# 14963   DR PAULO PEDROZO         PT          Esquerda    TO  MASCULINO
# 14964        ROMÁRIO PAZ        MDB            Centro    RS  MASCULINO
# 14965         DR.TANDICK  CIDADANIA          Esquerda    BA  MASCULINO
# 14966   MARIANA SERVENTE         PP           Direita    SE   FEMININO
#
#       DS_COR_RACA  NR_IDADE_DATA_POSSE  VR_BEM_CANDIDATO AGRUPAMENTO_BENS  \
# 0          BRANCA                 33.0          404854.0          BENS_G2
# 1          BRANCA                 53.0               NaN              NaN
# 2           PARDA                 35.0               NaN              NaN
# 3           PARDA                 44.0           70000.0          BENS_G4
# 4           PARDA                 60.0           15000.0          BENS_G4
# ...           ...                  ...               ...              ...
# 14962      BRANCA                 45.0           80000.0          BENS_G3
# 14963      BRANCA                 69.0          578341.0          BENS_G2
# 14964      BRANCA                 43.0          255145.0          BENS_G3
# 14965      BRANCA                 53.0         1025024.0          BENS_G1
# 14966       PARDA                 42.0               NaN              NaN
#
#                  DS_GRAU_INSTRUCAO  \
# 0                SUPERIOR COMPLETO
# 1            ENSINO MÉDIO COMPLETO
# 2      ENSINO FUNDAMENTAL COMPLETO
# 3                SUPERIOR COMPLETO
# 4            ENSINO MÉDIO COMPLETO
# ...                            ...
# 14962            SUPERIOR COMPLETO
# 14963            SUPERIOR COMPLETO
# 14964        ENSINO MÉDIO COMPLETO
# 14965            SUPERIOR COMPLETO
# 14966      ENSINO MÉDIO INCOMPLETO
#
#                                              DS_OCUPACAO ST_REELEICAO  \
# 0                                             ECONOMISTA            N
# 1      TÉCNICO DE ENFERMAGEM E ASSEMELHADOS (EXCETO E...            N
# 2                                           DONA DE CASA            N
# 3                                                 OUTROS            N
# 4                                            COMERCIANTE            N
# ...                                                  ...          ...
# 14962         ATLETA PROFISSIONAL E TÉCNICO EM DESPORTOS            N
# 14963                                             MÉDICO            N
# 14964                                         EMPRESÁRIO            N
# 14965                          SERVIDOR PÚBLICO ESTADUAL            N
# 14966                                             OUTROS            N
#
#              NM_EMAIL  NR_CANDIDATO
# 0      NÃO DIVULGÁVEL         13113
# 1      NÃO DIVULGÁVEL         18456
# 2      NÃO DIVULGÁVEL         65321
# 3      NÃO DIVULGÁVEL         12300
# 4      NÃO DIVULGÁVEL         51123
# ...               ...           ...
# 14962  NÃO DIVULGÁVEL         23015
# 14963  NÃO DIVULGÁVEL         13200
# 14964  NÃO DIVULGÁVEL         15111
# 14965  NÃO DIVULGÁVEL         23222
# 14966  NÃO DIVULGÁVEL         11110
#
# [14967 rows x 14 columns]

# %% [markdown]
# # candidatos a deputado federal!

# %%
candidatosDepFederal = pd.read_csv("candidatosDepFederal.csv")
candidatosDepFederal
# Out:
#         NM_URNA_CANDIDATO SG_PARTIDO IDEOLOGIA_PARTIDO SG_UF  DS_GENERO  \
# 0            DALVA MORAIS        MDB            Centro    AM   FEMININO
# 1        PROFESSORA LEILA     AVANTE            Centro    MG   FEMININO
# 2     MARISTELA PANEGALLI        PTB           Direita    RS   FEMININO
# 3      SUB OFICIAL CHEREM        PMN          Esquerda    AM  MASCULINO
# 4             PABLO AIRES        PSB          Esquerda    RN  MASCULINO
# ...                   ...        ...               ...   ...        ...
# 9313      GUIMARÃES DO PT         PT          Esquerda    CE  MASCULINO
# 9314          CLEUSA LARA      UNIÃO           Direita    MG   FEMININO
# 9315        LUIZ JACOMINI  CIDADANIA          Esquerda    RS  MASCULINO
# 9316   CAMILLA BARRETINHO       PSDB            Centro    MG   FEMININO
# 9317          JONAS MATOS     AVANTE            Centro    SC  MASCULINO
#
#      DS_COR_RACA  NR_IDADE_DATA_POSSE  VR_BEM_CANDIDATO AGRUPAMENTO_BENS  \
# 0          PARDA                 37.0            4800.0          BENS_G4
# 1          PARDA                 50.0          167102.0          BENS_G3
# 2         BRANCA                 50.0          495000.0          BENS_G2
# 3         BRANCA                 49.0               NaN              NaN
# 4          PARDA                 28.0           45000.0          BENS_G4
# ...          ...                  ...               ...              ...
# 9313      BRANCA                 65.0          859435.0          BENS_G1
# 9314      BRANCA                 55.0          936823.0          BENS_G1
# 9315      BRANCA                 36.0               0.0          BENS_G4
# 9316       PARDA                 32.0               NaN              NaN
# 9317      BRANCA                 42.0               NaN              NaN
#
#           DS_GRAU_INSTRUCAO                                     DS_OCUPACAO  \
# 0     ENSINO MÉDIO COMPLETO                                      EMPRESÁRIO
# 1         SUPERIOR COMPLETO  PROFESSOR E INSTRUTOR DE FORMAÇÃO PROFISSIONAL
# 2         SUPERIOR COMPLETO                      SERVIDOR PÚBLICO MUNICIPAL
# 3         SUPERIOR COMPLETO                       MEMBRO DAS FORÇAS ARMADAS
# 4         SUPERIOR COMPLETO                                        VEREADOR
# ...                     ...                                             ...
# 9313      SUPERIOR COMPLETO                                        DEPUTADO
# 9314      SUPERIOR COMPLETO                                      ECONOMISTA
# 9315      SUPERIOR COMPLETO                       SERVIDOR PÚBLICO ESTADUAL
# 9316  ENSINO MÉDIO COMPLETO                                          OUTROS
# 9317      SUPERIOR COMPLETO                                      EMPRESÁRIO
#
#      ST_REELEICAO        NM_EMAIL  NR_CANDIDATO
# 0               N  NÃO DIVULGÁVEL          1522
# 1               N  NÃO DIVULGÁVEL          7072
# 2               N  NÃO DIVULGÁVEL          1433
# 3               N  NÃO DIVULGÁVEL          3355
# 4               N  NÃO DIVULGÁVEL          4050
# ...           ...             ...           ...
# 9313            S  NÃO DIVULGÁVEL          1322
# 9314            N  NÃO DIVULGÁVEL          4499
# 9315            N  NÃO DIVULGÁVEL          2345
# 9316            N  NÃO DIVULGÁVEL          4501
# 9317            N  NÃO DIVULGÁVEL          7017
#
# [9318 rows x 14 columns]

# %% [markdown]
# # candidatos a senador!

# %%
candidatosSenador = pd.read_csv("candidatosSenador.csv")
candidatosSenador
# Out:
#               NM_URNA_CANDIDATO SG_PARTIDO IDEOLOGIA_PARTIDO SG_UF  DS_GENERO  \
# 0               EDSON APARECIDO        MDB            Centro    SP  MASCULINO
# 1                   ALVARO DIAS       PODE           Direita    PR  MASCULINO
# 2                RICARDO MELLÃO       NOVO           Direita    SP  MASCULINO
# 3                  SARA AZEVEDO       PSOL          Esquerda    MG   FEMININO
# 4                CARLOS EDUARDO        PDT          Esquerda    RN  MASCULINO
# ..                          ...        ...               ...   ...        ...
# 194     PROFESSOR JOÃO SANTIAGO       PSTU          Esquerda    PA  MASCULINO
# 195              PROFESSOR NADO     AVANTE            Centro    RS  MASCULINO
# 196                      CAMILO         PT          Esquerda    CE  MASCULINO
# 197  MANCHA COLETIVO SOCIALISTA       PSTU          Esquerda    SP  MASCULINO
# 198               RAYSSA FURLAN        MDB            Centro    AP   FEMININO
#
#     DS_COR_RACA  NR_IDADE_DATA_POSSE  VR_BEM_CANDIDATO AGRUPAMENTO_BENS  \
# 0        BRANCA                 65.0         5571194.0          BENS_G1
# 1        BRANCA                 78.0         2220952.0          BENS_G1
# 2        BRANCA                 37.0          233895.0          BENS_G3
# 3         PARDA                 37.0           45609.0          BENS_G4
# 4         PARDA                 63.0         2877489.0          BENS_G1
# ..          ...                  ...               ...              ...
# 194      BRANCA                 58.0               NaN              NaN
# 195      BRANCA                 58.0          350000.0          BENS_G2
# 196      BRANCA                 54.0          607371.0          BENS_G2
# 197       PRETA                 67.0          691364.0          BENS_G2
# 198      BRANCA                 35.0         1396733.0          BENS_G1
#
#        DS_GRAU_INSTRUCAO                                      DS_OCUPACAO  \
# 0      SUPERIOR COMPLETO                SERVIDOR PÚBLICO CIVIL APOSENTADO
# 1      SUPERIOR COMPLETO                                          SENADOR
# 2      SUPERIOR COMPLETO                                         ADVOGADO
# 3      SUPERIOR COMPLETO                        PROFESSOR DE ENSINO MÉDIO
# 4      SUPERIOR COMPLETO                                         ADVOGADO
# ..                   ...                                              ...
# 194    SUPERIOR COMPLETO                         SERVIDOR PÚBLICO FEDERAL
# 195    SUPERIOR COMPLETO  PROFESSOR DE ENSINO DE PRIMEIRO E SEGUNDO GRAUS
# 196    SUPERIOR COMPLETO                                         AGRÔNOMO
# 197  SUPERIOR INCOMPLETO            TRABALHADOR METALÚRGICO E SIDERÚRGICO
# 198    SUPERIOR COMPLETO                                           MÉDICO
#
#     ST_REELEICAO        NM_EMAIL  NR_CANDIDATO
# 0              N  NÃO DIVULGÁVEL           155
# 1              S  NÃO DIVULGÁVEL           190
# 2              N  NÃO DIVULGÁVEL           300
# 3              N  NÃO DIVULGÁVEL           500
# 4              N  NÃO DIVULGÁVEL           123
# ..           ...             ...           ...
# 194            N  NÃO DIVULGÁVEL           160
# 195            N  NÃO DIVULGÁVEL           700
# 196            N  NÃO DIVULGÁVEL           131
# 197            N  NÃO DIVULGÁVEL           161
# 198            N  NÃO DIVULGÁVEL           151
#
# [199 rows x 14 columns]

# %% [markdown]
# ## processamento de dados..

# %%
# fonte: https://dadosabertos.tse.jus.br/dataset/candidatos-2022
import pandas as pd
import glob
df = pd.read_csv("candidatos.csv", sep=";", encoding="ISO-8859-1")

# %%
faixa_bens = ['BENS_G4','BENS_G3','BENS_G2','BENS_G1']
bens = pd.read_csv("bens.csv", sep=";", encoding="ISO-8859-1")

bens['VR_BEM_CANDIDATO'] = bens['VR_BEM_CANDIDATO'].replace(",",".", regex= True)

bens['VR_BEM_CANDIDATO'] = bens['VR_BEM_CANDIDATO'].astype(float).round(0).astype(int)

somaBens = bens.groupby(['SQ_CANDIDATO']).agg({'VR_BEM_CANDIDATO':'sum'})
somaBens.to_csv("soma-bens-2018.csv")

somaBens = pd.read_csv("soma-bens-2018.csv", sep=",", encoding="utf-8")

df = pd.merge(df, somaBens, how='left', left_on=['SQ_CANDIDATO'], right_on=['SQ_CANDIDATO'])

df['AGRUPAMENTO_BENS'] = pd.qcut(df['VR_BEM_CANDIDATO'],4,precision=0,labels=faixa_bens)

# %%
ideologias = pd.read_csv("ideologia-partidos.csv", sep=",", encoding="utf-8")

df = pd.merge(df.astype("str"), ideologias.astype("str"), how='left', left_on=['SG_PARTIDO'], right_on=['PARTIDO'])

# %%
keep = ['DS_CARGO','NM_URNA_CANDIDATO','SG_PARTIDO','IDEOLOGIA_PARTIDO','SG_UF','DS_GENERO','DS_COR_RACA','NR_IDADE_DATA_POSSE','VR_BEM_CANDIDATO','AGRUPAMENTO_BENS','DS_GRAU_INSTRUCAO','DS_OCUPACAO','ST_REELEICAO','DS_SITUACAO_CANDIDATO_URNA','NM_EMAIL','NR_CANDIDATO']

df = df[keep]

# %%
candidatosDeferidos = df[(df['DS_SITUACAO_CANDIDATO_URNA']=='DEFERIDO')]

candidatosDepEstadual = candidatosDeferidos[(candidatosDeferidos['DS_CARGO']=='DEPUTADO ESTADUAL')]

candidatosDepEstadual = candidatosDepEstadual.drop(columns=["DS_CARGO","DS_SITUACAO_CANDIDATO_URNA"],axis=1)

candidatosDepEstadual.to_csv("candidatosDepEstadual.csv", index=False)

candidatosDepFederal = candidatosDeferidos[(candidatosDeferidos['DS_CARGO']=='DEPUTADO FEDERAL')]

candidatosDepFederal = candidatosDepFederal.drop(columns=["DS_CARGO","DS_SITUACAO_CANDIDATO_URNA"],axis=1)

candidatosDepFederal.to_csv("candidatosDepFederal.csv", index=False)

candidatosSenador = candidatosDeferidos[(candidatosDeferidos['DS_CARGO']=='SENADOR')]

candidatosSenador = candidatosSenador.drop(columns=["DS_CARGO","DS_SITUACAO_CANDIDATO_URNA"],axis=1)

candidatosSenador.to_csv("candidatosSenador.csv", index=False)
